# %%
print(f" Wel-come To My Day-1: Added Python beginner programs")
# Out:
#  Wel-come To My Day-1: Added Python beginner programs

# %%
print("HELLO")
# Out:
# HELLO

# %%
a=5
b=5
c=a+b
c
# Out:
# 10

# %%
num1=int(input("Enter the number :"))
num2=int(input("Enter the number :"))
add=num1+num2
print(f" Addition of {num1} and {num2} is :{add}")
# Out:
# Enter the number : 5
# Enter the number : 5
#  Addition of 5 and 5 is :10

# %%
a=5
b=5
c=a-b
c
# Out:
# 0

# %%
num1=int(input("Enter the number :"))
num2=int(input("Enter the number :"))
sub=num1-num2
print(f" subtraction of {num1} and {num2} is  {sub}")
# Out:
# Enter the number : 10
# Enter the number : 10
#  subtraction of 10 and 10 is  0

# %%
a=5
b=5
c=a*b
c
# Out:
# 25

# %%
num1=int(input("Enter the number :"))
num2=int(input("Enter the number :"))
multi=num1*num2
print(f"multiplication of {num1} and {num2} is :{multi}")
# Out:
# Enter the number : 2
# Enter the number : 2
# multiplication of 2 and 2 is :4

# %%
a=5
b=5
c=a/b
c
# Out:
# 1.0

# %%
num1=int(input("Enter the number:"))
num2=int(input("Enter the number :"))
div=num1/num2
print(f"Division of {num1} and {num2} is: {div}")
# Out:
# Enter the number: 10
# Enter the number : 5
# Division of 10 and 5 is: 2.0

# %%
a=5
b=5
c=a%b
c
# Out:
# 0

# %%
num1=int(input("enter the number:"))
num2=int(input("Enter the number :"))
mod=num1%num2
print(f"module of {num1} and {num2} is:{mod}")
# Out:
# enter the numberv: 5
# Enter the number : 5
# module of 5 and 5 is:0

# %%
R=int(input("Enter the radius"))
area=3.14*R**2
print(f" area of circle is {area}")
# Out:
# Enter the radius 2
#  area of circle is 12.56

# %%
num=int(input("Enter the number"))
sqrt=num**0.5
print(f" squre root of {num} is {sqrt}")
# Out:
# Enter the number 4
#  squre root of 4 is 2.0

# %%
ht=int(input("Enter the height"))
bs=int(input("Enter the base"))
TA=0.5*ht*bs
print(f"area of triangle {TA}")
# Out:
# Enter the height 3
# Enter the base 3
# area of triangle 4.5
