# %%
print(f" Wel-come To My Day-5: Added Python Tuple programs")
# Out:
#  Wel-come To My Day-5: Added Python Tuple programs

# %%
t1=()
print(type(t1))
# Out:
# <class 'tuple'>

# %%
t2=tuple()
print(type(t2))
# Out:
# <class 'tuple'>

# %%
t3=(10,50,100,20,30,90,40,50)

# %%
len(t3)
# Out:
# 8

# %%
sorted(t3)
# Out:
# [10, 20, 30, 40, 50, 50, 90, 100]

# %%
del t3[2] //del cannot delete an item from a tuple because a tuple is immutable. Tuple elements cannot be modified or removed after the tuple is created.//
# Out:
#   Cell In[41], line 1
#     del t3[2] //del cannot delete an item from a tuple because a tuple is immutable. Tuple elements cannot be modified or removed after the tuple is created.//
#               ^
# SyntaxError: invalid syntax

# %%
t3.count(50)
# Out:
# 2

# %%
t3.index(90)
# Out:
# 5
