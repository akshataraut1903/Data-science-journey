# %%
print(f" Wel-come To My Day-4: Added Python List programs")
# Out:
#  Wel-come To My Day-4: Added Python List programs

# %%
l1=[]
print(type(l1))
# Out:
# <class 'list'>

# %%
l2=list()
print(type(l2))
# Out:
# <class 'list'>

# %%
l3=[10,50,20,90,30,100]

# %%
l3[2]
# Out:
# 20

# %%
l3[-3]
# Out:
# 90

# %%
l3[1:5:1]
# Out:
# [50, 20, 90, 30]

# %%
l3[5:1:-1]
# Out:
# [100, 30, 90, 20]

# %%
l3[::]
# Out:
# [10, 50, 20, 90, 30, 100]

# %%
l3[::-1]
# Out:
# [100, 30, 90, 20, 50, 10]

# %%
len(l3)
# Out:
# 6

# %%
any(l3)
# Out:
# True

# %%
all(l3)
# Out:
# True

# %%
l3+[100,200,300]
# Out:
# [100, 200, 300, 100, 200, 300, 100, 200, 300]

# %%
l3*3 
l3
# Out:
# [100, 200, 300, 100, 200, 300]

# %%
l4=[10,50,20,90,100]

# %%
l4.append(150)
l4
# Out:
# [10, 50, 20, 90, 100, 150]

# %%
l4.insert(3,200)
l4
# Out:
# [10, 50, 20, 200, 200, 90, 100, 150]

# %%
sorted(l4)
# Out:
# [10, 20, 50, 90, 100, 150, 200, 200]

# %%
sorted(l4,reverse=True)
# Out:
# [200, 200, 150, 100, 90, 50, 20, 10]

# %%
l1=[10,50,30,90]

# %%
l1[2]=70
l1
# Out:
# [10, 50, 70, 90]

# %%
del l1[2]
l1
# Out:
# [10, 50, 90]

# %%
l4.pop()
l4
# Out:
# [10, 50, 20, 200, 200, 90, 100]

# %%
l4.pop(3)
l4
# Out:
# [10, 50, 20, 200, 90, 100]

# %%
l4.remove(100)
l4
# Out:
# [10, 50, 20, 200, 90]

# %%
del l4[3]
l4
# Out:
# [10, 50, 20, 90]

# %%
l4.clear()
l4
# Out:
# []
