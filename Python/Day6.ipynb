# %%
print(f" Wel-come To My Day-6: Added Python Set programs")
# Out:
#  Wel-come To My Day-6: Added Python Set programs

# %%
s1={}
print(type(s1))
# Out:
# <class 'dict'>

# %%
s2=set()
print(type(s2))
# Out:
# <class 'set'>

# %%
s3={50,20,90,70,10,40,30}
s3
# Out:
# {10, 20, 30, 40, 50, 70, 90}

# %%
s4={1,1,'ram','sham','ram',50.35,76}
s4
# Out:
# {1, 50.35, 76, 'ram', 'sham'}

# %%
s4[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 s4[1]
#
# TypeError: 'set' object is not subscriptable

# %%
s3.add(100)
s3
# Out:
# {10, 20, 30, 40, 50, 70, 90, 100}

# %%
s3.update([50,65,75])
s3
# Out:
# {10, 20, 30, 40, 50, 65, 70, 75, 90, 100}

# %%
s3.remove(70)
s3
# Out:
# {10, 20, 30, 40, 50, 65, 75, 90, 100}

# %%
s3.discard(40)
s3
# Out:
# {10, 20, 30, 50, 65, 75, 90, 100}

# %%
s3.discard(500)
s3
# Out:
# {10, 20, 30, 50, 65, 75, 90, 100}

# %%
a={10,20,50,40,50}
b={40,50,60,70,80}

# %%
a.intersection(b)
# Out:
# {40, 50}

# %%
a.union(b)
# Out:
# {10, 20, 40, 50, 60, 70, 80}

# %%
a.difference(b)
# Out:
# {10, 20}

# %%
b.difference(a)
# Out:
# {60, 70, 80}

# %%
numbers = {10, 20, 30}
numbers.clear()
print(numbers)
# Out:
# set()

# %%
len(numbers)
# Out:
# 0

# %%
numbers = {10, 20, 30,50,60,70,80,90,100,120}

# %%
len(numbers)
# Out:
# 10
