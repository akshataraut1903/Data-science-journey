# %%
print(f" Wel-come To My Day-2: Added Python beginner programs")
# Out:
#  Wel-come To My Day-2: Added Python beginner programs

# %%
n1=int(input("enter the number"))
n2=int(input("enter the number"))
if n1>n2:
    print(f" {n1} is Greater than {n2}")
elif n1>n2:
    print(f"{n2} is greater than {n1}")
elif n1==n2:
    print(f" {n1} and {n2} is Equal to")
# Out:
# enter the number 7
# enter the number 5
#  7 is Greater than 5

# %%
num=int(input("Enter the number"))
if num%2==0:
    print(" Positive")
else:
    print(" Negative number")
# Out:
# Enter the number -3
#  Negative number

# %%
num=int(input("Enter the number"))
if num%2==0:
    print("Even")
else:
    print("odd")
# Out:
# Enter the number 3
# odd

# %%
num=int(input("enter the number"))
i=1
if i<=10:
    print(num*i)
    i=+1
print("multiplication table")
# Out:
# enter the number 7
# 7
# multiplication table

# %%
age=int(input("Enter the age"))
if age>=18:
    print("You are eligible for a driving license")
else:
    print("You are not eligible for a driving license")
# Out:
# Enter the age 20
# You are eligible for a driving license

# %%
ch = input("Enter a character: ")
if ch == 'a' or ch == 'e' or ch == 'i' or ch == 'o' or ch == 'u' or ch == 'A' or ch == 'E' or ch == 'I' or ch == 'O' or ch == 'U':
    print("It is a Vowel.")
else:
    print("It is a Consonant.")
# Out:
# Enter a character:  a
# It is a Vowel.

# %%
marks=int(input("enter the marks"))
if marks>=75:
    print("Distiction")
elif marks>=35:
    print("Pass")
else:
    print("Fail")
# Out:
# enter the marks 80
# Distiction

# %%
ch=input("Enter a character:")
if ch>='A' and ch<='Z':
    print("Uppercase Letter")
elif ch>='a' and ch<='z':
    print("Lowercase Letter")
else:
    print("It is not an alphabet")
# Out:
# Enter a character: a
# Lowercase Letter

# %%
ch=input("Enter a character")
if ch>='0'and ch<='9':
    print("Its Digit")
elif(ch>='A' and ch<='Z') or (ch>='a' and ch<='z'):
    print("Its Alphabet")
else:
    print("Its special character")
# Out:
# Enter a character %
# Its special character

# %%
num=int(input("Enter the number"))
if num%2==0 or num%5==0:
    print("The number is divisible by 2 or 5.")
else:
    print("The number is not divisible by 2 or 5.")
# Out:
# Enter the number 7
# The number is not divisible by 2 or 5.
